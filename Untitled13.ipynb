# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
# Load and Explore the Fashion MNIST Dataset
 (X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Display the structure of the dataset
print(f'Training set shape: {X_train.shape}')
print(f'Test set shape: {X_test.shape}')
print(f'Number of classes: {len(np.unique(y_train))}')
# Out:
# Training set shape: (60000, 28, 28)
# Test set shape: (10000, 28, 28)
# Number of classes: 10

# %%
# Define class names for easier understanding
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
# Data Preprocessing
# Scale the pixel values to a range of 0 to 1
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# Reshape the data to fit the model's input requirements
X_train = X_train.reshape((X_train.shape[0], 28, 28, 1))
X_test = X_test.reshape((X_test.shape[0], 28, 28, 1))

# %%
# Convert labels to one-hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# Visualizations

# Display sample images from the dataset
def plot_sample_images(images, labels, class_names):
    plt.figure(figsize=(10,10))
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i].reshape(28, 28), cmap=plt.cm.binary)
        plt.xlabel(class_names[np.argmax(labels[i])])
    plt.show()

plot_sample_images(X_train, y_train, class_names)

# %%
# Bar chart showing the distribution of samples across different classes
def plot_class_distribution(labels, class_names):
    unique, counts = np.unique(np.argmax(labels, axis=1), return_counts=True)
    plt.figure(figsize=(10, 5))
    plt.bar(class_names, counts, color='skyblue')
    plt.xlabel('Class')
    plt.ylabel('Number of Samples')
    plt.title('Class Distribution in Fashion MNIST Dataset')
    plt.xticks(rotation=45)
    plt.show()

plot_class_distribution(y_train, class_names)

# %%
# Build an Artificial Neural Network

# Design the model
model = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
# Compile the Model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the Model
history = model.fit(X_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 8s 4ms/step - loss: 0.5144 - accuracy: 0.8161 - val_loss: 0.3972 - val_accuracy: 0.8561
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3750 - accuracy: 0.8636 - val_loss: 0.3648 - val_accuracy: 0.8687
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3413 - accuracy: 0.8732 - val_loss: 0.3503 - val_accuracy: 0.8733
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3202 - accuracy: 0.8817 - val_loss: 0.3628 - val_accuracy: 0.8692
# Epoch 5/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.2996 - accuracy: 0.8884 - val_loss: 0.3398 - val_accuracy: 0.8825
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2853 - accuracy: 0.8934 - val_loss: 0.3351 - val_accuracy: 0.8785
# Epoch 7/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2750 - accuracy: 0.8963 - val_loss: 0.3252 - val_accuracy: 0.8785
# Epoch 8/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.2613 - accuracy: 0.9015 - val_loss: 0.3305 - val_accuracy: 0.8817
# Epoch 9/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2511 - accuracy: 0.9062 - val_loss: 0.3213 - val_accuracy: 0.8866
# Epoch 10/10
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.2424 - accuracy: 0.9081 - val_loss: 0.3318 - val_accuracy: 0.8863

# %%
# Evaluate the Model
val_loss, val_accuracy = model.evaluate(X_test, y_test, verbose=2)
print(f'Validation Loss: {val_loss}')
print(f'Validation Accuracy: {val_accuracy}')
# Out:
# 313/313 - 1s - loss: 0.3591 - accuracy: 0.8784 - 636ms/epoch - 2ms/step
# Validation Loss: 0.35906246304512024
# Validation Accuracy: 0.8784000277519226

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Test Set Prediction

# Make predictions on the test set
predictions = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
# Function to plot predictions
def plot_predictions(images, predictions, true_labels, class_names, num=10):
    plt.figure(figsize=(20, 5))
    for i in range(num):
        plt.subplot(1, num, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i].reshape(28, 28), cmap=plt.cm.binary)
        predicted_label = np.argmax(predictions[i])
        true_label = np.argmax(true_labels[i])
        color = 'blue' if predicted_label == true_label else 'red'
        plt.xlabel(f"{class_names[predicted_label]}\n({class_names[true_label]})", color=color)
    plt.show()

plot_predictions(X_test, predictions, y_test, class_names)
